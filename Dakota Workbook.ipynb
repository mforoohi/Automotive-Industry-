# %%
import pandas as pd
import requests
import json
import csv

# %%
url=" https://data.bts.gov/resource/crem-w557.json?$where=auto_sales!=0"

# %%
print(requests.get(url))
# Out:
# <Response [200]>

# %%
response = requests.get(url)
response_json = response.json()
auto_sales_df=pd.DataFrame(response_json)
recent_sales=auto_sales_df.tail(77)
recent_sales=recent_sales[["date","auto_sales","heavy_truck_sales","light_truck_sales"]]
recent_sales.head()
# Out:
#                         date auto_sales heavy_truck_sales light_truck_sales
# 576  2015-01-01T00:00:00.000   515400.0           30700.0          632300.0
# 577  2015-02-01T00:00:00.000   558200.0           31300.0          696300.0
# 578  2015-03-01T00:00:00.000   717500.0           38000.0          824900.0
# 579  2015-04-01T00:00:00.000   646400.0           36200.0          797800.0
# 580  2015-05-01T00:00:00.000   748000.0           37100.0          884500.0

# %%
recent_sales['date']=recent_sales['date'].str.slice(0,4)
recent_sales.head()
# Out:
#      date auto_sales heavy_truck_sales light_truck_sales
# 576  2015   515400.0           30700.0          632300.0
# 577  2015   558200.0           31300.0          696300.0
# 578  2015   717500.0           38000.0          824900.0
# 579  2015   646400.0           36200.0          797800.0
# 580  2015   748000.0           37100.0          884500.0

# %%
#recent_sales=pd.to_numeric(recent_sales['date'],downcast="int")
recent_sales['auto_sales']=pd.to_numeric(recent_sales['auto_sales'],downcast="float")
#recent_sales=pd.to_numeric(recent_sales['heavy_truck_sales'],downcast="float")
#recent_sales=pd.to_numeric(recent_sales['light_truck_sales'],downcast="float")

recent_sales.head()
#recent_sales.groupby(recent_sales['date']).mean()
# Out:
#      date  auto_sales heavy_truck_sales light_truck_sales
# 576  2015    515400.0           30700.0          632300.0
# 577  2015    558200.0           31300.0          696300.0
# 578  2015    717500.0           38000.0          824900.0
# 579  2015    646400.0           36200.0          797800.0
# 580  2015    748000.0           37100.0          884500.0

# %%
av_monthly_sales=recent_sales.groupby(recent_sales['date']).mean()

# %%
av_monthly_sales.rename(columns = {"auto_sales":"average monthly sales"},inplace=True)
av_monthly_sales.reset_index()
#info from US Department of Transportation
# Out:
#    date  average monthly sales
# 0  2015           627375.00000
# 1  2016           573600.00000
# 2  2017           507433.34375
# 3  2018           442516.65625
# 4  2019           393316.65625
# 5  2020           283483.34375
# 6  2021           322560.00000

# %%
url="https://data.bts.gov/resource/crem-w557.json"
print(requests.get(url))
# Out:
# <Response [200]>

# %%
response = requests.get(url)
response_json = response.json()
auto_sales_df=pd.DataFrame(response_json)

# %%
transport_df=auto_sales_df[["date","system_use_u_s_airline",
                           "passenger_rail_passengers",
                           "transportation_economic_2",
                           "system_use_transit_ridership_1",
                          "system_use_transit_ridership",
                          "transportation_economic",
                          "auto_sales_saar_millions"]
                          ]

transport_df=transport_df.dropna()

# %%
transport_df['date']=transport_df['date'].str.slice(0,10)
transport_df=transport_df.rename(columns={"system_use_u_s_airline":"Domestic Flights",
                           "passenger_rail_passengers":"Passenger Rail Passengers",
                           "transportation_economic_2":"Personal Spending on Transportation Services",
                           "system_use_transit_ridership_1":"Use on Fixed Bus Routes",
                          "system_use_transit_ridership":"Use on Urban Rail",
                          "transportation_economic":"Personal Spending on Motor Vehicles and Parts",
                          "auto_sales_saar_millions":"Auto Sales in Millions"})

# %%
#Quarterly Transportation Data
transport_df
# Out:
#            date   Domestic Flights Passenger Rail Passengers  \
# 840  2017-01-01         61280000.0                 2330923.0
# 843  2017-04-01         61210000.0                 2764389.0
# 846  2017-07-01         62060000.0                 3012988.0
# 849  2017-10-01         62990000.0                 2788447.0
# 852  2018-01-01         63450000.0                 2308715.0
# 855  2018-04-01  64650000.00000001                 2595973.0
# 858  2018-07-01  65180000.00000001                 3063808.0
# 861  2018-10-01         65560000.0                 2809806.0
# 864  2019-01-01         65640000.0                 2288770.0
# 867  2019-04-01  67040000.00000001                 2728995.0
# 870  2019-07-01         67810000.0                 3108797.0
# 873  2019-10-01         67950000.0                 2856692.0
# 876  2020-01-01         69990000.0                 2399424.0
# 879  2020-04-01          2860000.0                  121154.0
# 882  2020-07-01         20300000.0                  572147.0
# 885  2020-10-01         27240000.0                  685989.0
# 888  2021-01-01         27640000.0                  487403.0
#
#     Personal Spending on Transportation Services Use on Fixed Bus Routes  \
# 840                               411206000000.0             379032287.0
# 843                           414624999999.99994             388066756.0
# 846                               422094000000.0             361210003.0
# 849                               431766000000.0             425403015.0
# 852                               440842000000.0             369920847.0
# 855                               436870000000.0             392252372.0
# 858                           432812999999.99994             362119816.0
# 861                           432252999999.99994             437208668.0
# 864                           434827000000.00006             367851089.0
# 867                           439804999999.99994             397479345.0
# 870                           447355000000.00006             369342381.0
# 873                           447840999999.99994             426401216.0
# 876                               414816000000.0             375834492.0
# 879                               267290000000.0             111116448.0
# 882                           339768999999.99994             182412121.0
# 885                           336907000000.00006             189059005.0
# 888                               345094000000.0             159021133.0
#
#     Use on Urban Rail Personal Spending on Motor Vehicles and Parts  \
# 840       385406234.0                            500251000000.00006
# 843       407072908.0                                502296000000.0
# 846       388539014.0                                515366000000.0
# 849       444700375.0                            534119000000.00006
# 852       381378921.0                            530979000000.00006
# 855       398115089.0                            536407000000.00006
# 858       394287833.0                                535746000000.0
# 861       443479335.0                                537098000000.0
# 864       368022820.0                            520592999999.99994
# 867       415533810.0                            534615000000.00006
# 870       411609150.0                            535079000000.00006
# 873       448819797.0                                539220000000.0
# 876       406474497.0                            495871000000.00006
# 879        42951341.0                            497308999999.99994
# 882        99378564.0                                574060000000.0
# 885       137304596.0                                573258000000.0
# 888       113532825.0                                649908000000.0
#
#     Auto Sales in Millions
# 840              6272000.0
# 843              6225000.0
# 846              5964000.0
# 849              6232000.0
# 852              5467000.0
# 855              5330000.0
# 858              5179000.0
# 861              5573000.0
# 864              5251000.0
# 867              4807000.0
# 870              4651000.0
# 873              4427000.0
# 876              4364000.0
# 879              1974000.0
# 882              3469000.0
# 885              3859000.0
# 888              3770000.0

# %%
file="Lockdown_days.csv"
lockdown_df=pd.read_csv(file)
lockdown_df=lockdown_df[['State/territory',
                         'State of emergency declared',
                         'Stay at home ordered',
                        'Face coverings required in public',
                        'Gatherings banned']]
lockdown_df.head(57)
# Out:
#                      State/territory State of emergency declared  \
# 0                            Alabama                      13-Mar
# 1                             Alaska                      11-Mar
# 2                     American Samoa                      29-Jan
# 3                            Arizona                      11-Mar
# 4                           Arkansas                      11-Mar
# 5    California(government response)                       4-Mar
# 6                           Colorado                      10-Mar
# 7                        Connecticut                      10-Mar
# 8                           Delaware                      12-Mar
# 9               District of Columbia                      11-Mar
# 10                           Florida                       1-Mar
# 11                           Georgia                      14-Mar
# 12                              Guam                      14-Mar
# 13                            Hawaii                       4-Mar
# 14                             Idaho                      13-Mar
# 15                          Illinois                       9-Mar
# 16                           Indiana                       6-Mar
# 17                              Iowa                       9-Mar
# 18                            Kansas                       9-Mar
# 19                          Kentucky                       6-Mar
# 20                         Louisiana                      11-Mar
# 21                             Maine                      15-Mar
# 22                          Maryland                       5-Mar
# 23                     Massachusetts                      10-Mar
# 24                          Michigan                      11-Mar
# 25                         Minnesota                      13-Mar
# 26                       Mississippi                       4-Mar
# 27                          Missouri                      13-Mar
# 28                           Montana                      12-Mar
# 29                          Nebraska                      13-Mar
# 30                            Nevada                      12-Mar
# 31                     New Hampshire                      13-Mar
# 32                        New Jersey                       9-Mar
# 33                        New Mexico                      11-Mar
# 34     New York(government response)                       7-Mar
# 35                    North Carolina                      10-Mar
# 36                      North Dakota                      13-Mar
# 37                              Ohio                       9-Mar
# 38                          Oklahoma                      15-Mar
# 39                            Oregon                       8-Mar
# 40                      Pennsylvania                       6-Mar
# 41                       Puerto Rico                      12-Mar
# 42                      Rhode Island                       9-Mar
# 43                    South Carolina                      13-Mar
# 44                      South Dakota                      13-Mar
# 45                         Tennessee                      12-Mar
# 46        Texas(government response)                      13-Mar
# 47                              Utah                       6-Mar
# 48               U.S. Virgin Islands                      13-Mar
# 49                           Vermont                      16-Mar
# 50                          Virginia                      12-Mar
# 51                        Washington                      Feb-29
# 52                     West Virginia                       4-Mar
# 53                         Wisconsin                      12-Mar
# 54                           Wyoming                      12-Mar
#
#                              Stay at home ordered  \
# 0                                           4-Apr
# 1                                          28-Mar
# 2                                              No
# 3                                          31-Mar
# 4                                              No
# 5                                          19-Mar
# 6                                          26-Mar
# 7                                          23-Mar
# 8                                          24-Mar
# 9                                          30-Mar
# 10                                          3-Apr
# 11                                          3-Apr
# 12                                             No
# 13                                         25-Mar
# 14                                         25-Mar
# 15                                         21-Mar
# 16                                         25-Mar
# 17                                             No
# 18                                         30-Mar
# 19                             March 26(advisory)
# 20                                         23-Mar
# 21                                          2-Apr
# 22                                         30-Mar
# 23                             March 24(advisory)
# 24                                         24-Mar
# 25                                         27-Mar
# 26                                          3-Apr
# 27                                          6-Apr
# 28                                         28-Mar
# 29                                             No
# 30                                          1-Apr
# 31                                         27-Mar
# 32                                         21-Mar
# 33                                         24-Mar
# 34                                         22-Mar
# 35                                         30-Mar
# 36                                             No
# 37                                         23-Mar
# 38                     April 2 (partial advisory)
# 39                                         23-Mar
# 40                                          1-Apr
# 41                                         15-Mar
# 42                                         28-Mar
# 43                                          7-Apr
# 44                                       Regional
# 45                                          2-Apr
# 46                                          2-Apr
# 47                                       Regional
# 48                                         25-Mar
# 49                                         25-Mar
# 50                                         30-Mar
# 51                                         23-Mar
# 52                                         23-Mar
# 53  March 25(declared unconstitutional on May 13)
# 54                                       Regional
#
#    Face coverings required in public  \
# 0                                Yes
# 1                                 No
# 2                                 No
# 3                                 No
# 4                                Yes
# 5                                Yes
# 6                                Yes
# 7                                Yes
# 8                                Yes
# 9                                Yes
# 10                                No
# 11                                No
# 12                                No
# 13                               Yes
# 14                                No
# 15                               Yes
# 16                               Yes
# 17                                No
# 18                               Yes
# 19                               Yes
# 20                               Yes
# 21                               Yes
# 22                               Yes
# 23                               Yes
# 24                               Yes
# 25                               Yes
# 26                                No
# 27                                No
# 28                                No
# 29                                No
# 30                               Yes
# 31                                No
# 32                               Yes
# 33                               Yes
# 34                               Yes
# 35                               Yes
# 36                                No
# 37                               Yes
# 38                                No
# 39                               Yes
# 40                                No
# 41                                No
# 42                               Yes
# 43                                No
# 44                                No
# 45                  Varies by county
# 46                               Yes
# 47                               Yes
# 48                                No
# 49                                No
# 50                               Yes
# 51                               Yes
# 52                               Yes
# 53                               Yes
# 54                                No
#
#                                     Gatherings banned
# 0                                          10 or more
# 1                                          10 or more
# 2                                          10 or more
# 3                                          50 or more
# 4                                          10 or more
# 5                                                 All
# 6                                          10 or more
# 7                                                 All
# 8                                                 All
# 9                                          10 or more
# 10                                         10 or more
# 11                                         10 or more
# 12                                                All
# 13  11 or more, and public gathering in public places
# 14                                                All
# 15                                                All
# 16     All outside, and 11 or more inside a household
# 17                                         10 or more
# 18                                         10 or more
# 19                                         10 or more
# 20                                         11 or more
# 21                                         10 or more
# 22                                         10 or more
# 23                                         11 or more
# 24                                                All
# 25                                                All
# 26                                                All
# 27                                         10 or more
# 28                                         10 or more
# 29                                         10 or more
# 30                                         10 or more
# 31                                         50 or more
# 32                                                All
# 33                                          6 or more
# 34                                                All
# 35                                         10 or more
# 36                                         50 or more
# 37                                         11 or more
# 38                                         11 or more
# 39                                                All
# 40                           10 or more (recommended)
# 41                                                All
# 42                                         25 or more
# 43                                         50 or more
# 44                                         50 or more
# 45                                         10 or more
# 46                                         10 or more
# 47                                         10 or more
# 48                                                All
# 49                                         10 or more
# 50                                         10 or more
# 51                                                All
# 52                                                All
# 53                                                All
# 54                                         10 or more

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
travel_habits_df=transport_df.set_index('date')
th=travel_habits_df.astype('float',copy=True)

th.head()
# Out:
#             Domestic Flights  Passenger Rail Passengers  \
# date
# 2017-01-01        61280000.0                  2330923.0
# 2017-04-01        61210000.0                  2764389.0
# 2017-07-01        62060000.0                  3012988.0
# 2017-10-01        62990000.0                  2788447.0
# 2018-01-01        63450000.0                  2308715.0
#
#             Personal Spending on Transportation Services  \
# date
# 2017-01-01                                  4.112060e+11
# 2017-04-01                                  4.146250e+11
# 2017-07-01                                  4.220940e+11
# 2017-10-01                                  4.317660e+11
# 2018-01-01                                  4.408420e+11
#
#             Use on Fixed Bus Routes  Use on Urban Rail  \
# date
# 2017-01-01              379032287.0        385406234.0
# 2017-04-01              388066756.0        407072908.0
# 2017-07-01              361210003.0        388539014.0
# 2017-10-01              425403015.0        444700375.0
# 2018-01-01              369920847.0        381378921.0
#
#             Personal Spending on Motor Vehicles and Parts  \
# date
# 2017-01-01                                   5.002510e+11
# 2017-04-01                                   5.022960e+11
# 2017-07-01                                   5.153660e+11
# 2017-10-01                                   5.341190e+11
# 2018-01-01                                   5.309790e+11
#
#             Auto Sales in Millions
# date
# 2017-01-01               6272000.0
# 2017-04-01               6225000.0
# 2017-07-01               5964000.0
# 2017-10-01               6232000.0
# 2018-01-01               5467000.0

# %%
dates=th.index
flights=th['Domestic Flights']
passenger_trains = th['Passenger Rail Passengers']
urban_rail = th['Use on Urban Rail']
bus = th['Use on Fixed Bus Routes']

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, sharex=True,figsize=(15,15))
fig.suptitle("Travel Habits", fontsize=16, fontweight="bold")
plt.xticks(rotation=90)

ax1.plot(dates, flights, linewidth=1, marker="o")
ax1.ticklabel_format(style='plain', useOffset=False, axis='y')
ax1.set_ylabel("Domestic flight use")

ax2.plot(dates, passenger_trains, linewidth=1, marker="o", color="r")
ax2.ticklabel_format(style='plain', useOffset=False, axis='y')
ax2.set_ylabel("Passenger train use")

ax3.plot(dates, urban_rail, linewidth=1, marker="o", color="g")
ax3.ticklabel_format(style='plain', useOffset=False, axis='y')
ax3.set_ylabel("urban rails use")
#ax3.set_xlabel("quarters")

ax4.plot(dates, bus, linewidth=1, marker="o", color="y")
ax4.ticklabel_format(style='plain', useOffset=False, axis='y')
ax4.set_ylabel("Bus use")
ax4.set_xlabel("quarters")
plt.tight_layout()

plt.show()

# %%
plt.plot(dates, flights, color="blue", label="Use on Domestic Flights" )
plt.ticklabel_format(style='plain', useOffset=False, axis='y') 
plt.plot(dates, bus, color="red", label="Use of Fixed Bus Routes" )
plt.ticklabel_format(style='plain', useOffset=False, axis='y') 
#passenger_trains = plt.plot(travel_habits_df['date'], travel_habits_df['Passenger Rail Passengers'], color="green", label="Use on Passenger Rail" )

#urban_rail = plt.plot(quarters, transport_df['Use on Urban Rail'], color="red", label="Use on Urban Rail" )

#bus = plt.plot(quarters, transport_df['Use on Fixed Bus Routes'], color="yellow", label="Use on Fixed Bus Routes" )


plt.legend(handles=[flights,# passenger_trains, urban_rail, 
                    bus
                   ], loc="best")

#plt.axes.Axes.set_ylim(ymin=2000000,ymax=71500000)
# Show the chart
plt.xticks(rotation=45)
plt.show()
                                          
#date	Domestic Flights	Passenger Rail Passengers	Personal Spending on Transportation Services	Use on Fixed Bus Routes	Use on Urban Rail	Personal Spending on Motor Vehicles and Parts	Auto Sales in Millions
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-8ab5d7fe221d> in <module>
#      10
#      11
# ---> 12 plt.legend(handles=[flights,# passenger_trains, urban_rail,
#      13                     bus
#      14                    ], loc="best")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in legend(*args, **kwargs)
#    2736 @_copy_docstring_and_deprecators(Axes.legend)
#    2737 def legend(*args, **kwargs):
# -> 2738     return gca().legend(*args, **kwargs)
#    2739
#    2740
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     409         .. plot:: gallery/text_labels_and_annotations/legend.py
#     410         """
# --> 411         handles, labels, extra_args, kwargs = mlegend._parse_legend_args(
#     412                 [self],
#     413                 *args,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/legend.py in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1180
#    1181     elif handles is not None and labels is None:
# -> 1182         labels = [handle.get_label() for handle in handles]
#    1183
#    1184     elif labels is not None and handles is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/legend.py in <listcomp>(.0)
#    1180
#    1181     elif handles is not None and labels is None:
# -> 1182         labels = [handle.get_label() for handle in handles]
#    1183
#    1184     elif labels is not None and handles is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'get_label'

# %%
file2="../csv/applemobilitytrends-2021-07-28.csv"
mobility_df=pd.read_csv(file2)
#mobility_df.columns
us_mobility_df=mobility_df.loc[mobility_df['region']=='United States']
us_mobility_df=us_mobility_df.set_index('transportation_type')
#us_mobility_df.to_csv('/Users/owner/Desktop/DataClass/Project 1/Car_Dealership/csv/us_mobility.csv')
clean_us_mobility_df=us_mobility_df.drop(['geo_type','region','alternative_name','country','sub-region'],1)
clean_us_mobility_df=clean_us_mobility_df.T
clean_us_mobility_df=clean_us_mobility_df.astype('float')
clean_us_mobility_df=clean_us_mobility_df.reset_index()
clean_us_mobility_df['index']=pd.to_datetime(clean_us_mobility_df['index'])
clean_us_mobility_df=clean_us_mobility_df.rename(columns={'index':'date'})
clean_us_mobility_df
# Out:
# /Users/owner/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# transportation_type       date  driving  transit  walking
# 0                   2020-01-13   100.00   100.00   100.00
# 1                   2020-01-14   102.97    97.77    99.59
# 2                   2020-01-15   105.19    98.84   101.87
# 3                   2020-01-16   108.48    99.04   100.60
# 4                   2020-01-17   125.51   108.03   121.36
# ..                         ...      ...      ...      ...
# 558                 2021-07-24   180.94   109.94   219.84
# 559                 2021-07-25   143.50    89.38   154.41
# 560                 2021-07-26   153.15    97.73   158.85
# 561                 2021-07-27   154.95    97.60   160.81
# 562                 2021-07-28   157.75    99.22   164.12
#
# [563 rows x 4 columns]

# %%
import matplotlib.dates as mdates
f, axs = plt.subplots(3,1,figsize=(15,15))
plt.subplot(3,1,1)
plt.plot(clean_us_mobility_df['date'],clean_us_mobility_df['driving'],'b')
plt.xlabel('Date')
plt.ylabel('Adjusted Apple Maps Calls')
plt.title('US Driving Stats')

plt.subplot(3,1,2)
plt.plot(clean_us_mobility_df['date'],clean_us_mobility_df['walking'],'g')
plt.xlabel('Date')
plt.ylabel('Adjusted Apple Maps Calls')
plt.title('US Walking Stats')

plt.subplot(3,1,3)
plt.plot(clean_us_mobility_df['date'],clean_us_mobility_df['transit'],'r')
plt.xlabel('Date')
plt.ylabel('Adjusted Apple Maps Calls')
plt.title('US Transit Stats')
#clean_us_mobility_df[['driving','transit','walking']].plot(label="US Mobility Trends")
#plt.xticks([])
#fmt_quarter_year = mdates.MonthLocator(interval=4)
#ax.xaxis.set_major_locator(fmt_quarter_year)
plt.tight_layout()

#f.set_figheight(15)
#f.set_figwidth(15)
#average_unemployment.plot(label="World Average")
#combined_unemployed_data.loc['USA', "2010":"2014"].plot(label="United States")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
file3="../csv/us_mobility_grouped.csv"
usacsv_df=pd.read_csv(file3)
usa_df=usacsv_df[['Date','driving','transit','walking']]
#,'% change driving','% change walking','% change transit']]
usa_df
# Out:
#           Date  driving  transit  walking
# 0   2020-01-31  2032.99  1883.63  2004.91
# 1   2020-02-29  3315.22  2967.19  3310.80
# 2   2020-03-31  2645.84  1838.73  2418.56
# 3   2020-04-30  1834.91   730.33  1507.28
# 4   2020-05-31  2819.08   926.55  2376.65
# 5   2020-06-30  3828.00  1337.47  3338.40
# 6   2020-07-31  4271.82  1586.25  3788.26
# 7   2020-08-31  4358.74  1693.77  4119.18
# 8   2020-09-30  4029.32  1702.05  3873.82
# 9   2020-10-31  3963.76  1742.73  3839.57
# 10  2020-11-30  3199.12  1466.73  3127.95
# 11  2020-12-31  3249.72  1386.75  3222.43
# 12  2021-01-31  3161.89  1412.48  3052.12
# 13  2021-02-28  2971.08  1403.67  2899.91
# 14  2021-03-31  3814.42  1757.38  3776.97
# 15  2021-04-30  4111.71  2002.08  4153.56
# 16  2021-05-31  4500.12  2331.48  4671.55
# 17  2021-06-30  4805.04  2781.08  5046.66
# 18  2021-07-31  4555.59  2779.97  4907.16

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex=True)
fig.suptitle("Travel Habits", fontsize=16, fontweight="bold")
plt.xticks(rotation=90)

ax1.plot(dates, flights, linewidth=1, marker="o")
ax1.ticklabel_format(style='plain', useOffset=False, axis='y')
ax1.set_ylabel("flights")

ax2.plot(dates, passenger_trains, linewidth=1, marker="o", color="r")
ax2.ticklabel_format(style='plain', useOffset=False, axis='y')
ax2.set_ylabel("Passenger train")

ax3.plot(dates, urban_rail, linewidth=1, marker="o", color="g")
ax3.ticklabel_format(style='plain', useOffset=False, axis='y')
ax3.set_ylabel("walking")
ax3.set_xlabel("Months")



plt.show()
